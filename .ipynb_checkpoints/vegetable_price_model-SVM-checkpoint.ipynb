# %% [markdown]
# # 蔬菜价格预测模型
#
# 2018年4月25日
#
# 在这个项目中，我们将使用成都市蔬菜价格数据建立一个有关最高价和最低价的预测模型。探索多个常用的监督学习算法并找出其中最优的方案。

# %% [markdown]
# ## 1. 数据准备

# %% [markdown]
# ### 1.1 导入数据
#
# 首先从CSV文件中导入数据，计算每一条数据前3天和前9天价格平均值，然后将数据拆分为特征和目标两个部分。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#读取成都的蔬菜价格数据
data = pd.read_csv('./vegetable_prices.csv')
data['updateTime'] = pd.to_datetime(data['updateTime'])
#读取重庆的蔬菜价格数据
#data = pd.read_csv('./vegetable_prices_Chongqing.csv')
# calculating average prices 3 or 9 days before
data['h_3'] = data['h_price'].shift(1).rolling(window=3).mean()
data['h_9'] = data['h_price'].shift(1).rolling(window=9).mean()
data['l_3'] = data['l_price'].shift(1).rolling(window=3).mean()
data['l_9'] = data['l_price'].shift(1).rolling(window=9).mean()
data = data.dropna()

#通过索引来看，这里的编码是没问题的
# data_encoded = get_dummies(data, columns=['v_name','area','v_market'])
# data_encoded.to_csv("data_encoded.csv", sep=',', index=True, encoding='utf-8')
# data.to_csv("data_1.csv", sep=',', index=True, encoding='utf-8')

prices = data[['h_price', 'l_price']]
features = data.drop(['l_price', 'h_price', 'v_price'], axis=1)
print('chengdu vegetable dataset has {} data points with {} variables each'.format(*data.shape))
# Out:
# chengdu vegetable dataset has 7371 data points with 22 variables each

# %% [markdown]
# ### 1.2 分析数据
#
# 数据包含如下22个变量：

# %%
data.head()
# Out:
#    v_name  v_price  h_price  l_price             v_market area         source  \
# 9      生姜      7.2      8.0      6.6  四川成都龙泉聚和(国际)果蔬菜交易中心   cd  vegnet.com.cn
# 10     大蒜      8.4      8.8      7.8  四川成都龙泉聚和(国际)果蔬菜交易中心   cd  vegnet.com.cn
# 11     芹菜      4.8      5.2      4.5  四川成都龙泉聚和(国际)果蔬菜交易中心   cd  vegnet.com.cn
# 12     莴笋      2.4      3.0      2.1  四川成都龙泉聚和(国际)果蔬菜交易中心   cd  vegnet.com.cn
# 13     蒜薹      9.5     10.0      8.0  四川成都龙泉聚和(国际)果蔬菜交易中心   cd  vegnet.com.cn
#
#    updateTime  insertTime  yWendu    ...     fengli fengxiang  aqi aqiLevel  \
# 9  2016-03-01  2018-04-19       6    ...         微风        南风  137        3
# 10 2016-03-01  2018-04-19       6    ...         微风        南风  137        3
# 11 2016-03-01  2018-04-19       6    ...         微风        南风  137        3
# 12 2016-03-01  2018-04-19       6    ...         微风        南风  137        3
# 13 2016-03-01  2018-04-19       6    ...         微风        南风  137        3
#
#     aqiInfo    cpi       h_3       h_9       l_3       l_9
# 9      轻度污染  102.3  3.666667  3.377778  2.900000  2.666667
# 10     轻度污染  102.3  5.600000  4.066667  4.533333  3.266667
# 11     轻度污染  102.3  7.600000  4.855556  6.466667  4.000000
# 12     轻度污染  102.3  7.333333  4.833333  6.300000  4.033333
# 13     轻度污染  102.3  5.666667  4.555556  4.800000  3.733333
#
# [5 rows x 22 columns]

# %%
data.describe()
# Out:
#            v_price      h_price      l_price       yWendu       bWendu  \
# count  7371.000000  7371.000000  7371.000000  7371.000000  7371.000000
# mean      4.278974     4.882214     3.843664    12.125085    19.888211
# std       2.945466     3.311870     2.756567     7.613284     7.914107
# min       0.800000     0.900000     0.700000    -4.000000     4.000000
# 25%       2.000000     2.300000     1.800000     6.000000    13.000000
# 50%       3.600000     4.000000     3.200000    12.000000    19.000000
# 75%       5.000000     6.000000     4.500000    19.000000    27.000000
# max      16.500000    20.000000    16.000000    26.000000    36.000000
#
#                aqi     aqiLevel          cpi          h_3          h_9  \
# count  7371.000000  7371.000000  7371.000000  7371.000000  7371.000000
# mean     90.249084     2.277574   101.695387     4.881142     4.880273
# std      47.855732     0.961405     0.563581     1.998666     1.037054
# min      25.000000     1.000000   100.800000     1.166667     2.100000
# 25%      54.000000     2.000000   101.300000     3.333333     4.277778
# 50%      79.000000     2.000000   101.400000     4.500000     4.800000
# 75%     117.000000     3.000000   102.300000     6.133333     5.511111
# max     318.000000     6.000000   102.600000    12.333333     9.700000
#
#                l_3          l_9
# count  7371.000000  7371.000000
# mean      3.843135     3.842783
# std       1.626428     0.746328
# min       0.900000     1.666667
# 25%       2.533333     3.422222
# 50%       3.533333     3.888889
# 75%       4.700000     4.300000
# max       8.366667     6.811111

# %% [markdown]
# 以上是对原始数据集中的几个数值型变量进行的基本统计分析，可以看到均值，标准差，中位数和最值等基本描述统计量。

# %% [markdown]
# ### 1.3 数据分割与重排
# 接下来，先将数据集中的蔬菜名称转换为独热编码（One Hot Encoding），然后分成训练和测试两个子集并打乱数据顺序，消除数据集中由于顺序产生的偏差，分割比例为80%数据用于训练，20%用于测试。

# %%
from sklearn.model_selection import train_test_split
from pandas import get_dummies

features_encoded = get_dummies(features, columns=['v_name', 'tianqi','area','v_market','aqiInfo'])
X_train, X_test, y_train, y_test = train_test_split(features_encoded, prices, test_size=0.2, random_state=42)

print('dataset train: {} {}, test: {} {}'.format(
    X_train.shape, y_train.shape, X_test.shape, y_test.shape))
features_encoded.head()
# Out:
# dataset train: (5896, 83) (5896, 2), test: (1475, 83) (1475, 2)
#            source updateTime  insertTime  yWendu  bWendu fengli fengxiang  \
# 9   vegnet.com.cn 2016-03-01  2018-04-19       6      19     微风        南风
# 10  vegnet.com.cn 2016-03-01  2018-04-19       6      19     微风        南风
# 11  vegnet.com.cn 2016-03-01  2018-04-19       6      19     微风        南风
# 12  vegnet.com.cn 2016-03-01  2018-04-19       6      19     微风        南风
# 13  vegnet.com.cn 2016-03-01  2018-04-19       6      19     微风        南风
#
#     aqi  aqiLevel    cpi      ...       tianqi_阵雨~小雨  tianqi_阵雨~阴  area_cd  \
# 9   137         3  102.3      ...                  0            0        1
# 10  137         3  102.3      ...                  0            0        1
# 11  137         3  102.3      ...                  0            0        1
# 12  137         3  102.3      ...                  0            0        1
# 13  137         3  102.3      ...                  0            0        1
#
#     v_market_四川成都龙泉聚和(国际)果蔬菜交易中心  aqiInfo_严重污染  aqiInfo_中度污染  aqiInfo_优  \
# 9                              1             0             0          0
# 10                             1             0             0          0
# 11                             1             0             0          0
# 12                             1             0             0          0
# 13                             1             0             0          0
#
#     aqiInfo_良  aqiInfo_轻度污染  aqiInfo_重度污染
# 9           0             1             0
# 10          0             1             0
# 11          0             1             0
# 12          0             1             0
# 13          0             1             0
#
# [5 rows x 83 columns]

# %% [markdown]
# 独热编码后，变量增加到了41个，其中蔬菜名称变成了一系列数值型数据。

# %% [markdown]
# ## 2. 训练模型

# %% [markdown]
# ### 2.1 SVR模型
#
# 根据前面对数据进行的探索性分析，我们得到如下结论：
#
# 1. 蔬菜最高价与“最低价”、“白天温度”、“夜晚温度”、“前3天最高价均值”、“前9天最高价均值”、“前3天最低价均值”、“前9天最低价均值”具有相关关系；
# 2. 蔬菜最低价与“最高价”、“前3天最高价均值”、“前9天最高价均值”、“前3天最低价均值”、“前9天最低价均值”具有相关关系；
#
# 首先需要在分割好的数据集中删掉不相关的变量，计算需要的变量。

# %%
X_train_lm = X_train.drop([
    'source', 
    'updateTime', 
    'insertTime', 
    'fengli', 
    'fengxiang', 
    'aqiLevel', 
    'cpi'
], axis=1)

X_test_lm = X_test.drop([
    'source', 
    'updateTime', 
    'insertTime', 
    'fengli', 
    'fengxiang', 
    'aqiLevel', 
    'cpi',
], axis=1)

X_train_lm.head()
# Out:
#       yWendu  bWendu  aqi       h_3       h_9       l_3       l_9  v_name_冬瓜  \
# 6241       0      12  118  3.666667  4.611111  2.166667  2.600000          0
# 2532      14      23   85  2.333333  2.866667  1.933333  2.400000          0
# 5247      14      20  151  4.766667  5.988889  3.600000  4.288889          0
# 5727       8      13  118  4.166667  5.355556  3.200000  4.177778          0
# 3299       8      13  248  2.100000  3.800000  1.700000  3.088889          0
#
#       v_name_南瓜  v_name_土豆      ...       tianqi_阵雨~小雨  tianqi_阵雨~阴  area_cd  \
# 6241          0          0      ...                  0            0        1
# 2532          0          0      ...                  0            0        1
# 5247          1          0      ...                  0            0        1
# 5727          0          0      ...                  0            0        1
# 3299          0          0      ...                  0            0        1
#
#       v_market_四川成都龙泉聚和(国际)果蔬菜交易中心  aqiInfo_严重污染  aqiInfo_中度污染  aqiInfo_优  \
# 6241                             1             0             0          0
# 2532                             1             0             0          0
# 5247                             1             0             1          0
# 5727                             1             0             0          0
# 3299                             1             0             0          0
#
#       aqiInfo_良  aqiInfo_轻度污染  aqiInfo_重度污染
# 6241          0             1             0
# 2532          1             0             0
# 5247          0             0             0
# 5727          0             1             0
# 3299          0             0             1
#
# [5 rows x 76 columns]

# %% [markdown]
# 下面将使用网格搜索和K折交叉验证的方法，基于SVR模型建立对价格的预测。

# %%
from sklearn.metrics import r2_score, make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR


def r2_score_metric(y_true, y_pred):
    score = r2_score(y_true, y_pred)
    return score

def fit_model(X, y, regressor, params):
    cross_validator = KFold(n_splits=5, shuffle=True, random_state=42)
    scoring_func = make_scorer(r2_score_metric)
    grid = GridSearchCV(estimator=regressor, param_grid=params, scoring=scoring_func, cv=cross_validator)
    grid = grid.fit(X, y)
    return grid.best_estimator_

# %%
def standard_column_X(df, column=['h_3','h_9','l_3','l_9','aqi','yWendu','bWendu']):
    column_mean = df[column].mean()
    column_std = df[column].std()
    df[column] = (df[column]-column_mean)/column_std
    return df
def standard_column_y(df, column=['h_price','l_price']):
    column_mean = df[column].mean()
    column_std = df[column].std()
    df[column] = (df[column]-column_mean)/column_std
    return df

# %%
#标准化训练数据
std_X_train_lm = standard_column_X(X_train_lm)
#std_y_train = standard_column_y(y_train)
std_X_test_lm = standard_column_X(X_test_lm)
#std_y_test = standard_column_y(y_test)

# %%
#print('paramter for the optimal model {}'.format(linear_regressor.get_params()))
svm_regressor_h = SVR(kernel='rbf', C=1e3, gamma=0.1)
svm_regressor_l = SVR(kernel='rbf', C=1e3, gamma=0.1)
#svm_regressor_h = SVR(kernel='rbf', C=550, gamma=0.1)
#svm_regressor_h = SVR(kernel='linear', C=1000)
#svm_regressor_l = SVR(kernel='rbf', C=65, gamma=0.1)
result_h = svm_regressor_h.fit(std_X_train_lm, y_train['h_price']).predict(std_X_test_lm)
result_l = svm_regressor_l.fit(std_X_train_lm, y_train['l_price']).predict(std_X_test_lm)
svm_regressor
print('paramter for the optimal model {}'.format(svm_regressor.get_params()))

# %%
# svm_regressor_h = GridSearchCV(SVR(kernel='rbf'), cv=5,  n_jobs = 3,
#                    param_grid={"C": [1e-1,1e0, 1e1, 1e2, 1e3, 1e4],  
#                                "gamma": [0.1,0.001,0.01, 1]})  
# result_h = svm_regressor_h.fit(std_X_train_lm, y_train['h_price']).predict(std_X_test_lm)
# print('paramter for the optimal model {}'.format(svm_regressor_h.get_params()))

# %%
r2_h = r2_score_metric(y_test['h_price'], result_h)
#r2_l = r2_score_metric(y_test['l_price'], result_l)
print('optimal model has R^2 score {:,.2f} on test data of h_price '.format(r2_h))
#print('optimal model has R^2 score {:,.2f} on test data of l_price '.format(r2_l))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-196-1edf147a1e98> in <module>()
# ----> 1 r2_h = r2_score_metric(y_test['h_price'], result_h)
#       2 #r2_l = r2_score_metric(y_test['l_price'], result_l)
#       3 print('optimal model has R^2 score {:,.2f} on test data of h_price '.format(r2_h))
#       4 #print('optimal model has R^2 score {:,.2f} on test data of l_price '.format(r2_l))
#
# <ipython-input-191-f84afaded2e4> in r2_score_metric(y_true, y_pred)
#       7
#       8 def r2_score_metric(y_true, y_pred):
# ----> 9     score = r2_score(y_true, y_pred)
#      10     return score
#      11
#
# D:\Anaconda\envs\py2\lib\site-packages\sklearn\metrics\regression.pyc in r2_score(y_true, y_pred, sample_weight, multioutput)
#     528     """
#     529     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 530         y_true, y_pred, multioutput)
#     531
#     532     if sample_weight is not None:
#
# D:\Anaconda\envs\py2\lib\site-packages\sklearn\metrics\regression.pyc in _check_reg_targets(y_true, y_pred, multioutput)
#      73
#      74     """
# ---> 75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#
# D:\Anaconda\envs\py2\lib\site-packages\sklearn\utils\validation.pyc in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [1475, 1045]

# %%
features_encoded_std = standard_column_X(features_encoded.drop([
    'source', 
    'updateTime', 
    'insertTime', 
    'fengli', 
    'fengxiang', 
    'aqiLevel', 
    'cpi',
], axis=1))

# %%
result_h_price = svm_regressor_h.predict(features_encoded_std)
result_l_price = svm_regressor_l.predict(features_encoded_std)
print result_h_price
# result = {"h_price_pred": result[:,0],
#           "l_price_pred": result[:,1]}
result = {"h_price_pred": result_h_price,
         "l_price_pred": result_l_price}
result = pd.DataFrame(result)
data1 = data.reset_index(drop=True)
data1.head()
#data1 = standard_column_X(data1)
#data1 = standard_column_y(data1)
result = data1.join(result)
result.head()
result.to_csv("out_chengdu_Svr.csv", sep=',', index=True, encoding='utf-8')
# Out:
# [ 8.08439056  8.87966923  5.08032633 ...  7.3780374  12.08444186
#   6.10329581]

# %%
result_prices_dasuan = result[result['v_name'] == '大蒜'][['h_price','h_price_pred', 'l_price','l_price_pred', 'updateTime']].reset_index(drop=True )
result_prices_dasuan.plot(x='updateTime',figsize=(15, 10), fontsize=13,linewidth=3.0)

# %% [markdown]
# ## 3. 结论

# %% [markdown]
# 将支持向量机的输入进行标准化后，训练效果较好，最高价格和最低价格的预测曲线与原始数据贴合度较高
